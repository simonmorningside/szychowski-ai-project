# %%
# Quick test
from battle_royale import load_student_agents

agents = load_student_agents("student_agents")
print(f"Loaded {len(agents)} agents successfully!")
for agent in agents:
    print(f"  - {agent.name}")
# Out:
# 📂 Loading student agents from: student_agents
# ======================================================================
#
# Found 1 Python files and 21 JSON files
#
# ✅ King kong                      from dough_tournament_agent.py
# ✅ Trust Builder                  from alex_brown_agent.json (JSON)
# ✅ Relationship Keeper            from alex_singh_agent.json (JSON)
# ✅ Risk Manager                   from bailey_gonzalez_agent.json (JSON)
# ✅ Stable Cooperator              from casey_thomas_agent.json (JSON)
# ✅ Balanced Trader                from casey_wong_agent.json (JSON)
# ✅ Betrayal Detector              from elliot_lopez_agent.json (JSON)
# ✅ Game Theory Expert             from elliot_wong_agent.json (JSON)
# ✅ Strategic Dove                 from finley_lee_agent.json (JSON)
# ✅ Equilibrium Finder             from hayden_gonzalez_agent.json (JSON)
# ✅ Quick Retaliator               from hayden_smith_agent.json (JSON)
# ✅ Cooperative Hawk               from jesse_garcia_agent.json (JSON)
# ✅ Dynamic Responder              from jordan_thomas_agent.json (JSON)
# ✅ Profit Maximizer               from logan_brown_agent.json (JSON)
# ✅ Reputation Defender            from morgan_chen_agent.json (JSON)
# ✅ Chaos Agent                    from morgan_lee_agent.json (JSON)
# ✅ Adaptive Survivor              from morgan_smith_agent.json (JSON)
# ✅ My Evolved Agent               from my_tournament_agent.json (JSON)
# ✅ Ruthless Optimizer             from quinn_brown_agent.json (JSON)
# ✅ Pattern Matcher                from quinn_martin_agent.json (JSON)
# ✅ Nash Seeker                    from taylor_gonzalez_agent.json (JSON)
# ✅ Opportunist Prime              from taylor_jackson_agent.json (JSON)
#
# 📊 Total agents loaded: 22
# ======================================================================
#
# Loaded 22 agents successfully!
#   - King kong
#   - Trust Builder
#   - Relationship Keeper
#   - Risk Manager
#   - Stable Cooperator
#   - Balanced Trader
#   - Betrayal Detector
#   - Game Theory Expert
#   - Strategic Dove
#   - Equilibrium Finder
#   - Quick Retaliator
#   - Cooperative Hawk
#   - Dynamic Responder
#   - Profit Maximizer
#   - Reputation Defender
#   - Chaos Agent
#   - Adaptive Survivor
#   - My Evolved Agent
#   - Ruthless Optimizer
#   - Pattern Matcher
#   - Nash Seeker
#   - Opportunist Prime

# %%
"""
Unit 6: Agent Battle Royale Tournament
"""

from battle_royale import run_battle_royale
import webbrowser
import os

print("🎮 Starting Unit 6 Tournament...")
print("This will generate:")
print("  1. tournament_results.json (raw data)")
print("  2. tournament_dashboard.html (interactive explorer)")
print("  3. tournament_bracket.png (bracket image)")
print("\n" + "="*70 + "\n")

# Run tournament
bracket_champ, rr_tournament, all_agents = run_battle_royale(
    folder_path="student_agents",
    bracket_rounds=100,
    rr_rounds=100,
    num_tournaments=3,
    save_bracket=True
)

print("\n🎉 Done! Opening dashboard in browser...")

# Automatically open the HTML file in default browser
html_file = "tournament_dashboard.html"
if os.path.exists(html_file):
    file_path = os.path.abspath(html_file)
    webbrowser.open('file://' + file_path)
    print(f"✅ Dashboard opened in browser!")
    print(f"   If it didn't open, manually open: {html_file}")
else:
    print(f"❌ Could not find {html_file}")
# Out:
# 🎮 Starting Unit 6 Tournament...
# This will generate:
#   1. tournament_results.json (raw data)
#   2. tournament_dashboard.html (interactive explorer)
#   3. tournament_bracket.png (bracket image)
#
# ======================================================================
#
#
# ████████╗██╗  ██╗███████╗    ██╗   ██╗██╗  ████████╗██╗███╗   ███╗ █████╗ ████████╗███████╗
# ╚══██╔══╝██║  ██║██╔════╝    ██║   ██║██║  ╚══██╔══╝██║████╗ ████║██╔══██╗╚══██╔══╝██╔════╝
#    ██║   ███████║█████╗      ██║   ██║██║     ██║   ██║██╔████╔██║███████║   ██║   █████╗
#    ██║   ██╔══██║██╔══╝      ██║   ██║██║     ██║   ██║██║╚██╔╝██║██╔══██║   ██║   ██╔══╝
#    ██║   ██║  ██║███████╗    ╚██████╔╝███████╗██║   ██║██║ ╚═╝ ██║██║  ██║   ██║   ███████╗
#    ╚═╝   ╚═╝  ╚═╝╚══════╝     ╚═════╝ ╚══════╝╚═╝   ╚═╝╚═╝     ╚═╝╚═╝  ╚═╝   ╚═╝   ╚══════╝
#
#  █████╗  ██████╗ ███████╗███╗   ██╗████████╗    ██████╗  █████╗ ████████╗████████╗██╗     ███████╗
# ██╔══██╗██╔════╝ ██╔════╝████╗  ██║╚══██╔══╝    ██╔══██╗██╔══██╗╚══██╔══╝╚══██╔══╝██║     ██╔════╝
# ███████║██║  ███╗█████╗  ██╔██╗ ██║   ██║       ██████╔╝███████║   ██║      ██║   ██║     █████╗
# ██╔══██║██║   ██║██╔══╝  ██║╚██╗██║   ██║       ██╔══██╗██╔══██║   ██║      ██║   ██║     ██╔══╝
# ██║  ██║╚██████╔╝███████╗██║ ╚████║   ██║       ██████╔╝██║  ██║   ██║      ██║   ███████╗███████╗
# ╚═╝  ╚═╝ ╚═════╝ ╚══════╝╚═╝  ╚═══╝   ╚═╝       ╚═════╝ ╚═╝  ╚═╝   ╚═╝      ╚═╝   ╚══════╝╚══════╝
#                                     UNIT 6: THE SHOWDOWN
#
# 📂 Loading student agents from: student_agents
# ======================================================================
#
# Found 1 Python files and 21 JSON files
#
# ✅ King kong                      from dough_tournament_agent.py
# ✅ Trust Builder                  from alex_brown_agent.json (JSON)
# ✅ Relationship Keeper            from alex_singh_agent.json (JSON)
# ✅ Risk Manager                   from bailey_gonzalez_agent.json (JSON)
# ✅ Stable Cooperator              from casey_thomas_agent.json (JSON)
# ✅ Balanced Trader                from casey_wong_agent.json (JSON)
# ✅ Betrayal Detector              from elliot_lopez_agent.json (JSON)
# ✅ Game Theory Expert             from elliot_wong_agent.json (JSON)
# ✅ Strategic Dove                 from finley_lee_agent.json (JSON)
# ✅ Equilibrium Finder             from hayden_gonzalez_agent.json (JSON)
# ✅ Quick Retaliator               from hayden_smith_agent.json (JSON)
# ✅ Cooperative Hawk               from jesse_garcia_agent.json (JSON)
# ✅ Dynamic Responder              from jordan_thomas_agent.json (JSON)
# ✅ Profit Maximizer               from logan_brown_agent.json (JSON)
# ✅ Reputation Defender            from morgan_chen_agent.json (JSON)
# ✅ Chaos Agent                    from morgan_lee_agent.json (JSON)
# ✅ Adaptive Survivor              from morgan_smith_agent.json (JSON)
# ✅ My Evolved Agent               from my_tournament_agent.json (JSON)
# ✅ Ruthless Optimizer             from quinn_brown_agent.json (JSON)
# ✅ Pattern Matcher                from quinn_martin_agent.json (JSON)
# ✅ Nash Seeker                    from taylor_gonzalez_agent.json (JSON)
# ✅ Opportunist Prime              from taylor_jackson_agent.json (JSON)
#
# 📊 Total agents loaded: 22
# ======================================================================
#
#
# ======================================================================
# 🏆 BRACKET TOURNAMENT: SINGLE ELIMINATION
# ======================================================================
#
# 🎲 22 agents randomly seeded
# 🏟️  5 rounds until champion
#
# ======================================================================
# ⚔️  ROUND 1
# ======================================================================
#
# ✅ Ruthless Optimizer        defeats Balanced Trader           (139-134)
# ✅ Risk Manager              defeats Reputation Defender       (134-124)
# ✅ King kong                 defeats Cooperative Hawk          (139-104)
# ✅ Opportunist Prime         defeats Pattern Matcher           (236-91)
# ✅ Strategic Dove            defeats Betrayal Detector         (146-96)
# ✅ Adaptive Survivor         defeats Equilibrium Finder        (211-76)
# ✅ Relationship Keeper       defeats Game Theory Expert        (165-145)
# ✅ My Evolved Agent          defeats Trust Builder             (118-108)
# ✅ Profit Maximizer          defeats Stable Cooperator         (177-97)
# ✅ Nash Seeker               defeats Dynamic Responder         (165-95)
# ✅ Quick Retaliator          defeats Chaos Agent               (160-130)
#
# ======================================================================
# ⚔️  ROUND 2
# ======================================================================
#
# 🤝 TIE: Ruthless Optimizer vs Risk Manager (138-138) - SUDDEN DEATH!
# ⚡ Ruthless Optimizer        wins sudden death! (27-22)
# ✅ King kong                 defeats Opportunist Prime         (138-103)
# ✅ Adaptive Survivor         defeats Strategic Dove            (104-99)
# ✅ My Evolved Agent          defeats Relationship Keeper       (190-185)
# ✅ Nash Seeker               defeats Profit Maximizer          (121-106)
# 👋 Quick Retaliator          gets a bye (advances automatically)
#
# ======================================================================
# ⚔️  ROUND 3
# ======================================================================
#
# ✅ King kong                 defeats Ruthless Optimizer        (147-112)
# ✅ Adaptive Survivor         defeats My Evolved Agent          (110-105)
# ✅ Nash Seeker               defeats Quick Retaliator          (149-94)
#
# ======================================================================
# ⚔️  ROUND 4
# ======================================================================
#
# ✅ Adaptive Survivor         defeats King kong                 (113-103)
# 👋 Nash Seeker               gets a bye (advances automatically)
#
# ======================================================================
# 🏆 FINALS
# ======================================================================
#
# ✅ Adaptive Survivor         defeats Nash Seeker               (112-97)
#
# ======================================================================
# 🎉 TOURNAMENT CHAMPION 🎉
# ======================================================================
#
# 👑 Adaptive Survivor
#    by Morgan Smith
#
#    Survived 5 rounds of elimination!
# ======================================================================
# c:\Users\szych\Downloads\APAI class\szychowski-ai-project\Act 2\battle_royale.py:411: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\szych\Downloads\APAI class\szychowski-ai-project\Act 2\battle_royale.py:411: UserWarning: Glyph 128081 (\N{CROWN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\szych\Downloads\APAI class\szychowski-ai-project\Act 2\battle_royale.py:412: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=300, bbox_inches='tight', facecolor='white')
# c:\Users\szych\Downloads\APAI class\szychowski-ai-project\Act 2\battle_royale.py:412: UserWarning: Glyph 128081 (\N{CROWN}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=300, bbox_inches='tight', facecolor='white')
# ✅ Bracket saved to: tournament_bracket.png
# c:\Users\szych\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\szych\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128081 (\N{CROWN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ======================================================================
# 📊 COMPREHENSIVE ROUND-ROBIN TOURNAMENT
# ======================================================================
#
# Every agent plays every other agent 3 time(s)
# Each match: 100 rounds
# Total matches: 1386
# ======================================================================
#
# Running 3 tournament(s) with 22 agents...
#
# Tournament 1/3
#
# Tournament 2/3
#
# Tournament 3/3
# Tournament complete!
#
# ======================================================================
# 🏆 FINAL COMPREHENSIVE RANKINGS
# ======================================================================
#
# 🥇  1. My Evolved Agent              : 10,067 points
# 🥈  2. King kong                     : 9,988 points
# 🥉  3. Stable Cooperator             : 9,721 points
#     4. Relationship Keeper           : 9,422 points
#     5. Chaos Agent                   : 9,357 points
#     6. Adaptive Survivor             : 9,180 points  👑 BRACKET CHAMPION
#     7. Strategic Dove                : 9,000 points
#     8. Opportunist Prime             : 8,852 points
#     9. Nash Seeker                   : 8,835 points
#    10. Balanced Trader               : 8,809 points
#    11. Trust Builder                 : 8,757 points
#    12. Risk Manager                  : 8,727 points
#    13. Profit Maximizer              : 8,672 points
#    14. Reputation Defender           : 8,664 points
#    15. Ruthless Optimizer            : 8,496 points
#    16. Cooperative Hawk              : 8,443 points
#    17. Quick Retaliator              : 8,359 points
#    18. Betrayal Detector             : 8,335 points
#    19. Pattern Matcher               : 8,263 points
#    20. Dynamic Responder             : 8,109 points
#    21. Game Theory Expert            : 8,035 points
#    22. Equilibrium Finder            : 7,729 points
#
# ======================================================================
# 📈 DETAILED PERFORMANCE STATISTICS
# ======================================================================
#
# Agent                           Wins  Win Rate  Avg Score
# ----------------------------------------------------------------------
# My Evolved Agent                  97    77.0%      162.7
# King kong                         93    73.8%      161.9
# Stable Cooperator                 11     8.7%      156.6
# Relationship Keeper              109    86.5%      149.6
# Chaos Agent                       49    38.9%      144.8
# Adaptive Survivor                122    96.8%      146.2
# Strategic Dove                   100    79.4%      142.6
# Opportunist Prime                 65    51.6%      139.8
# Nash Seeker                       98    77.8%      141.2
# Balanced Trader                   70    55.6%      138.5
# Trust Builder                     80    63.5%      140.1
# Risk Manager                      52    41.3%      138.2
# Profit Maximizer                  80    63.5%      136.7
# Reputation Defender               52    41.3%      137.9
# Ruthless Optimizer                44    34.9%      132.8
# Cooperative Hawk                  49    38.9%      132.1
# Quick Retaliator                  49    38.9%      133.3
# Betrayal Detector                 36    28.6%      131.5
# Pattern Matcher                    4     3.2%      131.6
# Dynamic Responder                 33    26.2%      129.5
# Game Theory Expert                15    11.9%      127.0
# Equilibrium Finder                11     8.7%      121.9
#
# ======================================================================
# 🤔 BRACKET vs ROUND-ROBIN COMPARISON
# ======================================================================
#
# 👑 Bracket Champion:      Adaptive Survivor
#    Round-Robin Rank:      #6
#
# 🏆 Round-Robin Champion:  My Evolved Agent
#
# 💡 Lesson: Single elimination is exciting but can be random!
#    The most consistent performer wins the comprehensive tournament.
#
# ======================================================================
# 🏅 SUPERLATIVE AWARDS
# ======================================================================
#
# 🤝 MOST COOPERATIVE: My Evolved Agent
#    Average score: 162.7 (achieves mutual cooperation)
#
# ⚔️  MOST AGGRESSIVE: Adaptive Survivor
#    Wins: 122 (96.8% win rate)
#
# 📊 MOST CONSISTENT: Profit Maximizer
#    Score std dev: 29.8 (very predictable)
#
# 🎯 BIGGEST UPSET: Equilibrium Finder
#    Defeated Stable Cooperator (ranked 19 spots higher)
#
# 💥 GLASS CANNON: Pattern Matcher
#    Scored 306 points vs Stable Cooperator in single game
#
# 🎖️  PARTICIPATION TROPHY: Equilibrium Finder
#    Finished last but showed up! (7,729 points)
# ======================================================================
#
# ======================================================================
# 👥 ALL STUDENT AGENTS - FIND YOURS!
# ======================================================================
#
# Student                   Agent Name                       Rank      Score
# --------------------------------------------------------------------------------
# 🥇 my_tournament_agent       My Evolved Agent                  1     10,067
# 🥈 Doug Dahl                 King kong                         2      9,988
# 🥉 Casey Thomas              Stable Cooperator                 3      9,721
#    Alex Singh                Relationship Keeper               4      9,422
#    Morgan Lee                Chaos Agent                       5      9,357
#    Morgan Smith              Adaptive Survivor                 6      9,180
#    Finley Lee                Strategic Dove                    7      9,000
#    Taylor Jackson            Opportunist Prime                 8      8,852
#    Taylor Gonzalez           Nash Seeker                       9      8,835
#    Casey Wong                Balanced Trader                  10      8,809
#    Alex Brown                Trust Builder                    11      8,757
#    Bailey Gonzalez           Risk Manager                     12      8,727
#    Logan Brown               Profit Maximizer                 13      8,672
#    Morgan Chen               Reputation Defender              14      8,664
#    Quinn Brown               Ruthless Optimizer               15      8,496
#    Jesse Garcia              Cooperative Hawk                 16      8,443
#    Hayden Smith              Quick Retaliator                 17      8,359
#    Elliot Lopez              Betrayal Detector                18      8,335
#    Quinn Martin              Pattern Matcher                  19      8,263
#    Jordan Thomas             Dynamic Responder                20      8,109
#    Elliot Wong               Game Theory Expert               21      8,035
#    Hayden Gonzalez           Equilibrium Finder               22      7,729
#
# ======================================================================
# 💾 EXPORTING TOURNAMENT DATA
# ======================================================================
#
# ✅ Tournament data exported to: tournament_results.json
#    Total agents: 22
#    Total matches: 1386
#    File size: 244.6 KB
#
# ======================================================================
# 🌐 GENERATING INTERACTIVE DASHBOARD
# ======================================================================
#
# ✅ Interactive dashboard generated: tournament_dashboard.html
#    Open this file in your browser to explore results!
#    Features:
#      - Searchable tables
#      - Tabbed interface
#      - Bracket visualization
#      - Superlative awards
#
# 🎉 Done! Opening dashboard in browser...
# ✅ Dashboard opened in browser!
#    If it didn't open, manually open: tournament_dashboard.html

# %%
# ============================================================================
# REFLECTION QUESTIONS
# ============================================================================

print("\n" + "="*70)
print("📝 REFLECTION QUESTIONS FOR YOUR WRITEUP")
print("="*70)
print("""
Look at the "ALL STUDENT AGENTS" table above to find your ranking.

1. Tournament Performance Analysis
   - What was your agent's final rank?
   - How did you perform in bracket vs. round-robin?
   - Were the results similar or different? Why might that be?

2. Strategy Analysis
   - Look at the top 3 agents. What strategies do they use?
   - Compare them to your agent's strategy (your evolved genes)
   - What made the winning strategies successful?

3. Bracket vs. Round-Robin
   - Was the Bracket Champion the same as Round-Robin Champion?
   - If different, what does this teach you about tournament formats?
   - Which format better reflects true agent quality? Why?

4. Superlative Awards
   - Which superlative award did your agent win (if any)?
   - What trade-offs do different strategies make?
   - Would you rather have high win rate or high total score?

5. Generalization Lesson
   - Your agent was trained on 10 random opponents in Unit 5
   - It competed against 20+ agents here (most unseen)
   - How did this affect your agent's performance?
   - What would you change if you could redesign for THIS environment?

6. Game Theory Insights
   - Is there a "best" strategy that beats everyone?
   - Why or why not? (Hint: Think about opponent diversity)
   - What real-world situations mirror this tournament dynamic?

SUBMISSION: Write a 1-2 page reflection answering these questions.
Include your rank, total score, and what you learned about
evolutionary optimization and game theory.
""")

print("\n" + "="*70)
print("🎉 THANK YOU FOR PARTICIPATING!")
print("="*70)
